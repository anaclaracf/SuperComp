# %% [markdown]
# ## Relatório Algoritmo Busca Local com Aleatoriedade
#
# Aluna: Ana Clara Carneiro de Freitas
#
# ----------------------------------------------

# %% [markdown]
# ## Execução
#
# Inicialmente, foi utilizado o programa apresentado abaixo para gerar a entrada que o algoritmo ingênuo utilizará. Este gera um arquivo txt apelidado de **input** com quatro linhas, as quais indicam, respectivamente:
# - o tamanho da primeira sequência
# - o tamanho da segunda sequência
# - a primeira sequência
# - a segunda sequência

# %% [raw]
# import random
# n = 10 # tamanho da primeira sequência
# m = 40 # tamanho da segunda sequência
# file = 'input' # nome do arquivo a ser gerado
# f = open(file, 'w')
# seq=[str(n)+'\n',
#      str(m)+'\n',
#      ''.join(random.choices(['A','T','C','G','-'],k=n))+'\n',
#      ''.join(random.choices(['A','T','C','G','-'],k=m))]
# f.writelines(seq)
# f.close()
# print(''.join(seq))

# %% [markdown]
# Com o arquivo de entrada estabelecido, o próximo passo realizado no projeto foi compilar o mesmo com o comando apresentado abaixo, gerando um executável denominado **algoritmo**.
#
# `g++ -Wall -O3 main.cpp -o algoritmo`

# %% [markdown]
# Com o executável gerado, o código abaixo permite que o programa desenvolvido em c++ seja rodado, recebendo como entradas o arquivo input, criado acima, e gerando um arquivo txt denominado **output** com as sequências alinhadas.

# %% [raw]
# import subprocess
# import time
#
# with open('input') as f:
#     start = time.perf_counter()
#     proc = subprocess.run(['./algoritmo'], input=f.read(), text=True, capture_output=True)
#     end = time.perf_counter()
#
#     print('Tempo total(s):', end - start)

# %% [markdown]
# O arquivo apresentado abaixo é o resultado do score máximo entre as duas sub sequências utilizadas. Este algoritmo foi rodado diversas vezes para que fosse possível analisar de forma mais precisa os resultados e o comportamento em relação aos valores aleatórios k e p.

# %%
output_file = open("output", "r")

print(output_file.read())
# Out:
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: G
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTA
# sub sequencia B utilizada: GGA-TGC-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: GCA-CTA-A
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGTAG
# sub sequencia B utilizada: -ACG-GAGGA
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: -T
# sub sequencia B utilizada: -C
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: -TTT
# sub sequencia B utilizada: -CAA
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: C-TTTTGTAG
# sub sequencia B utilizada: -CAGGTGCA-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: C-TTTTGTA
# sub sequencia B utilizada: TGC--CAAG
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: TGTAG
# sub sequencia B utilizada: GGA-T
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: C-TTTTG
# sub sequencia B utilizada: CA-CTA-
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGT
# sub sequencia B utilizada: AGCG--CA
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTG
# sub sequencia B utilizada: A-TGC-
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: A
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TGTAG
# sub sequencia B utilizada: CTA-A
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: CAGGTGCA-
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: A
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGTA
# sub sequencia B utilizada: CG--CAGGT
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGT
# sub sequencia B utilizada: A-ACG-GA
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: GT
# sub sequencia B utilizada: G-
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: C
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TGTA
# sub sequencia B utilizada: TGC-
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGTAG
# sub sequencia B utilizada: CG-GAGGA-T
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: -
# sub sequencia B utilizada: -
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: --CAGGTGC
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTGTAG
# sub sequencia B utilizada: -CTA-A
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: TAG
# sub sequencia B utilizada: -AC
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: TAG
# sub sequencia B utilizada: AGG
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: GTAG
# sub sequencia B utilizada: CTA-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTGTAG
# sub sequencia B utilizada: CTA-AC
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: -ACG-GAGG
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: TGCA-CTA
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: G-GAGGA-T
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: C-TTT
# sub sequencia B utilizada: A-ACG
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: -
# sub sequencia B utilizada: -
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: T
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: AGGTGCA-C
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TGTAG
# sub sequencia B utilizada: GGTGC
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: CAGGTGCA-
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: GT
# sub sequencia B utilizada: GA
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: C-
# sub sequencia B utilizada: CG
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTT
# sub sequencia B utilizada: GCA-CT
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: TTTGTAG
# sub sequencia B utilizada: CG-GAGG
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: G
# sub sequencia B utilizada: A
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: TT
# sub sequencia B utilizada: TG
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGTA
# sub sequencia B utilizada: GAGCG--CA
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTG
# sub sequencia B utilizada: GA-TGC
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: -TT
# sub sequencia B utilizada: -AC
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: C-
# sub sequencia B utilizada: CA
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTGTAG
# sub sequencia B utilizada: A-CTA-A
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: GGTGCA-C
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: A
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTGT
# sub sequencia B utilizada: A-TGC
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: GTAG
# sub sequencia B utilizada: GCG-
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: TT
# sub sequencia B utilizada: TA
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: GT
# sub sequencia B utilizada: CA
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: C-TT
# sub sequencia B utilizada: GCG-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: -CTA-ACG
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGT
# sub sequencia B utilizada: -ACG-GAG
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: G
# sub sequencia B utilizada: A
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: ACG-GAGG
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: GTAG
# sub sequencia B utilizada: -CAA
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: A
# sub sequencia B utilizada: -
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: AGGA-TGC-
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: TGTAG
# sub sequencia B utilizada: -CAAG
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: TTGTAG
# sub sequencia B utilizada: GCA-CT
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGTAG
# sub sequencia B utilizada: AGCG--CAGG
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: TTGT
# sub sequencia B utilizada: AGGT
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: C-TTT
# sub sequencia B utilizada: --CAG
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTGTA
# sub sequencia B utilizada: -TGC--
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: AG
# sub sequencia B utilizada: A-
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: GTAG
# sub sequencia B utilizada: GA-T
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: -T
# sub sequencia B utilizada: --
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: -
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: GGTGCA-C
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: C-TTTTGT
# sub sequencia B utilizada: GGA-TGC-
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: A
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: -TT
# sub sequencia B utilizada: --C
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTT
# sub sequencia B utilizada: A-CTA
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: A-CTA-AC
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: -
# sub sequencia B utilizada: T
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTGTAG
# sub sequencia B utilizada: A-TGC--
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: C-TTTTGT
# sub sequencia B utilizada: A-ACG-GA
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TGTA
# sub sequencia B utilizada: GTGC
# -----------------------------------
# Max Score: 3
# sub sequencia A utilizada: TTGTAG
# sub sequencia B utilizada: GAGGA-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: C-TTTT
# sub sequencia B utilizada: C--CAA
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTA
# sub sequencia B utilizada: GGA-TGC-
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: C
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTTGTAG
# sub sequencia B utilizada: CTA-ACG
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: C
# sub sequencia B utilizada: -
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: C-TTT
# sub sequencia B utilizada: --CAG
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: C-TTTTGTAG
# sub sequencia B utilizada: -GAGGA-TGC
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: C-TTTTGTAG
# sub sequencia B utilizada: GTGCA-CTA-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: -CTA-ACG-
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: T
# sub sequencia B utilizada: C
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: -TTTTGTAG
# sub sequencia B utilizada: -CTA-ACG-
# -----------------------------------
# Max Score: 2
# sub sequencia A utilizada: AG
# sub sequencia B utilizada: AC
# -----------------------------------
# Max Score: 0
# sub sequencia A utilizada: C
# sub sequencia B utilizada: -
# -----------------------------------
# Max Score: 5
# sub sequencia A utilizada: TTTTGTAG
# sub sequencia B utilizada: AGGTGCA-
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: TTGTAG
# sub sequencia B utilizada: AGGTGC
# -----------------------------------
# Max Score: 4
# sub sequencia A utilizada: C-TT
# sub sequencia B utilizada: C--C
# -----------------------------------

# %% [markdown]
# ------------------------------
# ## Validação
#
# Para validar se os resultados obtidos pelo programa eram o esperado, foi utilizado o [Simulador online do Algoritmo de Smith-Waterman](http://rna.informatik.uni-freiburg.de/Teaching/index.jsp?toolName=Smith-Waterman). As imagens apresentadas abaixo indicam que os resultados foram de fato iguais.

# %% [markdown]
# - Resultado gerado pelo código implementado:
#
#     - Input
#
#        ![input](img/input.png)
#
#     - Um dos outputs do programa
#
#        ![input](img/output.png)

# %% [markdown]
# - Resultado gerado pelo Simulador:
# ![input](img/simulador.png)
